# %% [markdown]
# # Jupyter Notebook — Marcelo Gomes de Moraes
#
# **Disciplina:** Ciência dos Dados para Tomadas de Decisões
# **Atividade 1** — Exploração do dataset de cartão de crédito - **Exercício 1**
#
# *Achei a atividade bem interessante, principalmente a parte de explorar os dados com o pandas.*

# %%
conda list
# Out:
# # packages in environment at C:\Users\marcelo.gomes\anaconda3:
# #
# # Name                           Version               Build               Channel
# _anaconda_depends                2025.12               py313_mkl_0
# aiobotocore                      2.25.0                py313haa95532_0
# aiodns                           3.5.0                 py313haa95532_1
# aiohappyeyeballs                 2.6.1                 py313haa95532_0
# aiohttp                          3.13.2                py313h02ab6af_0
# aioitertools                     0.12.0                py313haa95532_0
# aiosignal                        1.4.0                 py313haa95532_0
# alabaster                        0.7.16                py313haa95532_0
# altair                           5.5.0                 py313haa95532_0
# anaconda-anon-usage              0.7.5                 pyhb46e38b_100
# anaconda-auth                    0.12.3                py313haa95532_0
# ...

# %%
python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 python
#
# NameError: name 'python' is not defined

# %% [markdown]
# # Jupyter Notebook — Marcelo Gomes de Moraes
#
# **Disciplina:** Ciência dos Dados para Tomadas de Decisões
# **Atividade 1** — Exploração do dataset de cartão de crédito - **Exercício 2**

# %%
import pandas as pd

# %%
pd.read_excel
# Out:
# <function pandas.io.excel._base.read_excel(io, sheet_name: 'str | int | list[IntStrT] | None' = 0, *, header: 'int | Sequence[int] | None' = 0, names: 'SequenceNotStr[Hashable] | range | None' = None, index_col: 'int | str | Sequence[int] | None' = None, usecols: 'int | str | Sequence[int] | Sequence[str] | Callable[[str], bool] | None' = None, dtype: 'DtypeArg | None' = None, engine: "Literal['xlrd', 'openpyxl', 'odf', 'pyxlsb', 'calamine'] | None" = None, converters: 'dict[str, Callable] | dict[int, Callable] | None' = None, true_values: 'Iterable[Hashable] | None' = None, false_values: 'Iterable[Hashable] | None' = None, skiprows: 'Sequence[int] | int | Callable[[int], object] | None' = None, nrows: 'int | None' = None, na_values=None, keep_default_na: 'bool' = True, na_filter: 'bool' = True, verbose: 'bool' = False, parse_dates: 'list | dict | bool' = False, date_parser: 'Callable | lib.NoDefault' = <no_default>, date_format: 'dict[Hashable, str] | str | None' = None, thousands: 
# ...

# %%
df = pd.read_excel('default_of_credit_card_clients__courseware_version_1_21_19.xls')

# %%
# Pergunta 1 — Quantas colunas?
print("Número de colunas:", df.shape[1])
print("Nomes:", df.columns.tolist())
# Out:
# Número de colunas: 25
# Nomes: ['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default payment next month']

# %%
# Pergunta 2 — Quantas linhas (amostras)?
print("Número de linhas:", df.shape[0])
# Out:
# Número de linhas: 30000

# %%
# Pergunta 3 — Tipos de características
print(df.dtypes)
print("\nNuméricas:", df.select_dtypes(include='number').columns.tolist())
print("Não-numéricas:", df.select_dtypes(exclude='number').columns.tolist())
# Out:
# ID                            object
# LIMIT_BAL                      int64
# SEX                            int64
# EDUCATION                      int64
# MARRIAGE                       int64
# AGE                            int64
# PAY_1                         object
# PAY_2                          int64
# PAY_3                          int64
# PAY_4                          int64
# PAY_5                          int64
# PAY_6                          int64
# BILL_AMT1                      int64
# BILL_AMT2                      int64
# BILL_AMT3                      int64
# BILL_AMT4                      int64
# BILL_AMT5                      int64
# BILL_AMT6                      int64
# PAY_AMT1                       int64
# PAY_AMT2                       int64
# PAY_AMT3                       int64
# PAY_AMT4                       int64
# PAY_AMT5                       int64
# PAY_AMT6                       int64
# default payment next month     int64
# dtype: object
#
# ...

# %%
# Pergunta 4 — Aparência dos dados
df.describe()   # Resumo estatístico das colunas numéricas
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    165760.989333      1.586500      1.833333      1.535900     35.108800
# std     130158.590432      0.513348      0.807699      0.542698      9.851592
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_2         PAY_3         PAY_4         PAY_5         PAY_6  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.132867     -0.164333     -0.219300     -0.263900     -0.288033
# ...

# %%
# Pergunta 5 — Dados faltando?
print("Valores nulos por coluna:")
print(df.isnull().sum())
print("\nTotal de valores nulos:", df.isnull().sum().sum())
# Out:
# Valores nulos por coluna:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_1                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64
#
# Total de valores nulos: 0

# %% [markdown]
# ### Conclusão da Análise Exploratória
# Nesta atividade, validei a integridade do dataset de cartões de crédito.
# O arquivo contém 30.000 amostras sem valores nulos. Notei que as variáveis
# como LIMIT_BAL (limite) e AGE (idade) são numéricas, enquanto outras como
# SEX e EDUCATION são categóricas codificadas.
# O ambiente Jupyter integrado ao GitHub facilita a reprodutibilidade da análise.
